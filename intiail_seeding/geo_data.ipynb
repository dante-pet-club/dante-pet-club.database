# %%
import pandas as pd


parquet_dir = "../parquet"
cities_df = pd.read_parquet(f"{parquet_dir}/cities_test.parquet")
states_df = pd.read_parquet(f"{parquet_dir}/states_test.parquet")
countries_df = pd.read_parquet(f"{parquet_dir}/countries_test.parquet")
# cities_df = pd.read_parquet(f"{parquet_dir}/cities_clean.parquet")
# states_df = pd.read_parquet(f"{parquet_dir}/states_clean.parquet")
# countries_df = pd.read_parquet(f"{parquet_dir}/countries_clean.parquet")

# %%
states_df.iloc[0].to_dict()
# Out:
# {'id': 2880, 'name': 'Atlántico', 'country_id': 48}

# %%
for index, row in cities_df.iterrows():
    print(row.to_dict())
# Out:
# {'id': 20485, 'name': 'Abejorral', 'state_id': 2890}
# {'id': 20487, 'name': 'Abriaquí', 'state_id': 2890}
# {'id': 20504, 'name': 'Alejandría', 'state_id': 2890}
# {'id': 20512, 'name': 'Amagá', 'state_id': 2890}
# {'id': 20513, 'name': 'Amalfi', 'state_id': 2890}
# {'id': 20520, 'name': 'Andes', 'state_id': 2890}
# {'id': 20521, 'name': 'Angelópolis', 'state_id': 2890}
# {'id': 20522, 'name': 'Angostura', 'state_id': 2890}
# {'id': 20747, 'name': 'Anorí', 'state_id': 2890}
# {'id': 20527, 'name': 'Anza', 'state_id': 2890}
# {'id': 20529, 'name': 'Apartadó', 'state_id': 2890}
# {'id': 20541, 'name': 'Arboletes', 'state_id': 2890}
# {'id': 20544, 'name': 'Argelia', 'state_id': 2890}
# {'id': 20551, 'name': 'Armenia', 'state_id': 2890}
# {'id': 20566, 'name': 'Barbosa', 'state_id': 2890}
# {'id': 20579, 'name': 'Bello', 'state_id': 2890}
# {'id': 20580, 'name': 'Belmira', 'state_id': 2890}
# {'id': 20588, 'name': 'Betania', 'state_id': 2890}
# ...
